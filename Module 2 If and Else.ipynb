# %%
secret = 4

guess = 10

if guess < secret:
    print('too low')
elif guess > secret:
    print('too high')
else:
    print('just right')
# Out:
# too high

# %%
secret = 4

guess = 2

if guess < secret:
    print('too low')
elif guess > secret:
    print('too high')
else:
    print('just right')
# Out:
# too low

# %%
secret = 4

guess = 4

if guess < secret:
    print('too low')
elif guess > secret:
    print('too high')
else:
    print('just right')
# Out:
# just right

# %%
small = True
green = True

if small:
    if green:
        print("That's a pea.")
    else:
        print("That's a cherry.")
else:
    if green:
        print("That's a watermelon.")
    else:
        print("That's a pumpkin.")
# Out:
# That's a pea.

# %%
small = True
green = False

if small:
    if green:
        print("That's a pea.")
    else:
        print("That's a cherry.")
else:
    if green:
        print("That's a watermelon.")
    else:
        print("That's a pumpkin.")
# Out:
# That's a cherry.

# %%
small = False
green = True

if small:
    if green:
        print("That's a pea.")
    else:
        print("That's a cherry.")
else:
    if green:
        print("That's a watermelon.")
    else:
        print("That's a pumpkin.")
# Out:
# That's a watermelon.

# %%
small = False
green = False

if small:
    if green:
        print("That's a pea.")
    else:
        print("That's a cherry.")
else:
    if green:
        print("That's a watermelon.")
    else:
        print("That's a pumpkin.")
# Out:
# That's a pumpkin.
