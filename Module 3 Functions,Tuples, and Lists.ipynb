# %%
things = ["mozzarella", "cinderella", "salmonella"]

# %%
things[1] = things[1].capitalize()

# %%
print(things)
# Out:
# ['mozzarella', 'Cinderella', 'salmonella']

# %%
things[0] = things[0].upper()
print(things)
# Out:
# ['MOZZARELLA', 'Cinderella', 'salmonella']

# %%
del things[2]
print(things)
# Out:
# ['MOZZARELLA', 'Cinderella']

# %%
#For the question in 7.5, yes, the starting letter C in :Cinderella" was changed from lowercase to uppercase!

# %%
#The following prompts answer 9.1 and 9.2's questions.

# %%
def good():
    return ['Harry', 'Ron', 'Hermione']
print(good())
# Out:
# ['Harry', 'Ron', 'Hermione']

# %%
def get_odds():
    for number in range(10):
        if number % 2 != 0:
            yield number
count = 0
for odd in get_odds():
    count += 1
    if count == 3:
        print(odd)
        break
# Out:
# 5
